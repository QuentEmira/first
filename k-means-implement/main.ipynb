# %%
import numpy as np
import pandas as pd
import k_means

# %%
data = pd.read_csv("../data.csv")

# %%
data.shape
# Out:
# (54761, 8)

# %%
data.dropna(inplace = True)

# %%
data.drop_duplicates(inplace=True)

# %%
data = data[data["Longitude"]>10]

# %%
data.shape
# Out:
# (53198, 8)

# %%
lat_long = data[['Latitude','Longitude']]

# %%
lat_long.head()
# Out:
#     Latitude  Longitude
# 0  12.753042  80.002606
# 1  12.691710  79.974238
# 2  12.763205  80.003638
# 3  12.759006  80.006993
# 4  12.744115  79.990242

# %%
clust = k_means.k_means(lat_long,k =1330)

# %%
clust.show_centroids()
